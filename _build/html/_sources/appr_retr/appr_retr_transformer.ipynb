# %% [markdown]
# # Moving Circles Transformer

# %%
import numpy as np
import pickle
import time
from matplotlib import pyplot as plt
import gc
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import confusion_matrix

device = "cuda" if torch.cuda.is_available() else "cpu"
#device = "cpu"

# %%
class Transformer(nn.Module):
    def __init__(self, n_input, n_output, seq_len, n_head, dim_ff, num_layers, position_encoding):
        super().__init__()

        self.n_input = n_input
        self.n_output = n_output
        self.n_head = n_head
        self.dim_ff = dim_ff
        self.num_layers = num_layers
        self.position_encoding = position_encoding
        self.seq_len = seq_len

        self.transformerlayer = nn.TransformerEncoderLayer(n_input, n_head, dim_feedforward=dim_ff, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(self.transformerlayer, num_layers)
        self.fc = nn.Linear(n_input, n_output)

    def position_encode(self):
        pe = torch.zeros(self.seq_len, self.n_input).to(device)
        pos = torch.arange(0, self.seq_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, self.n_input, 2).float() * (-np.log(10000.0) / self.n_input))

        pe[:, 0::2] = torch.sin(pos * div_term)
        pe[:, 1::2] = torch.cos(pos * div_term)
        pe = pe.unsqueeze(0)
        return pe
    
    def forward(self, X):
        x = X.to(device)
        if self.position_encoding:
            pe = self.position_encode()
            pe = pe.expand(X.size(0), -1, -1)
            x = X + pe
        y = self.transformer_encoder(x)
        y = self.fc(y)
        return y

# %%
class TransformerModel:
    def __init__(self, lstm, loss_fn, optimizer, seq_len, n_output, model_name="transformer"):
        self.model = lstm
        self.loss_fn = loss_fn
        self.optim = optimizer
        self.seq_len = seq_len
        self.n_output = n_output
        self.model_name = model_name

    def train(self, train_loader, n_epochs=10, learning=1e-2):
        train_loss = []
        best_loss = 1e10

        self.model.train()
        
        for i in range(n_epochs):
            start = time.time()
            avg_loss = 0.
            for X, y in train_loader:
                loss = 0.
                curr_batch_size = X.shape[0]

                X, y = X.to(device), y.to(device)
                self.optim.zero_grad()

                output = self.model(X)

                output = torch.transpose(output, 1, 2)
                y = torch.transpose(y, 1, 2)

                loss += self.loss_fn(output, y)
                
                loss.backward()
                self.optim.step()
                avg_loss += loss.item()

            end = time.time()
            epoch_mins, epoch_secs = self.epoch_time(start, end)
            if best_loss > avg_loss:
                best_loss = avg_loss
                torch.save({self.model_name: self.model.state_dict(), self.model_name+"_optimizer": self.optim.state_dict()}, self.model_name+'-model.pt')

            train_loss.append(avg_loss)
            
            print("Epoch " + str(i + 1) + "/" + str(n_epochs))
            print("Time: " + str(epoch_mins) + " minutes " + str(epoch_secs) + " seconds")
            print("Training loss: " + str(avg_loss))
            print()

        return train_loss
    
    def epoch_time(self, start_time, end_time):
        elapsed = end_time - start_time
        elapsed_mins = int(elapsed / 60)
        elapsed_secs = int(elapsed - (elapsed_mins * 60))
        return elapsed_mins, elapsed_secs

    def find_lens(self, X):
        X_lens = []
        for batch in X:
            count = 0
            for time in batch:
                if torch.count_nonzero(time) == 0:
                    break
                else:
                    count += 1
            X_lens.append(count)
        return X_lens

    def eval(self, test_loader):
        check = torch.load(self.model_name+"-model.pt")
        self.model.load_state_dict(check[self.model_name])

        confusion = np.zeros((self.n_output, self.n_output))

        gc.collect()
        torch.cuda.empty_cache()

        with torch.no_grad():
            correct = np.zeros(self.seq_len)
            total = np.zeros(self.seq_len)
            test_loss = 0.
            self.model.eval()

            for x, y in test_loader:
                curr_batch_size = x.shape[0]
                X, Y = x.to(device), y.to(device)

                output = self.model(X)

                X_lens = self.find_lens(X)

                top_value, top_index = output.topk(1)
                out = torch.zeros(curr_batch_size, self.seq_len, self.n_output).to(device)
                for clip in range(curr_batch_size):
                    for k in range(self.seq_len):
                        out[clip][k][top_index[clip][k].item()] = 1

                output = torch.transpose(output, 1, 2)
                y_hat = torch.transpose(y, 1, 2).to(device)
                test_loss += self.loss_fn(output, y_hat).item()
                correct, total = accuracy(y.cpu().numpy(), out.cpu().numpy(), correct, total)

                true, pred = devector(y.cpu().numpy(), out.cpu().numpy())

                confusion += confusion_matrix(true, pred)
        
        ff_accuracy = correct / total
        return ff_accuracy, confusion
    
    
    def random_samples(self, X, pad=0.):
        X_random = []
        X_lens = self.find_lens(X)
        for i in range(X.shape[0]):
            X_batch = np.random.normal(size=(X_lens[i], X.shape[-1]))
            if X_lens[i] < self.seq_len:
                X_pad = np.array([[pad]*X.shape[-1]]*(self.seq_len - X_lens[i]))
                X_batch = np.append(X_batch, X_pad, axis=0)
            X_random.append(X_batch)
        X_random = np.array(X_random)
        return X_random
    
    def rand_test(self, test_loader, n_samples=20, percentile=90):
        rand_acc_array = []
        for sample in range(n_samples):
            correct = np.zeros(self.seq_len)
            total = np.zeros(self.seq_len)
            
            self.model.eval()

            with torch.no_grad():

                for x, y in test_loader:
                    loss = 0.
                    curr_batch_size = x.shape[0]
                    X_random = torch.from_numpy(self.random_samples(x)).float().to(device)
                    y = y.to(device)

                    X_lens = self.find_lens(x)
                    output = self.model(X_random)
                    top_value, top_index = output.topk(1)
                    out = torch.zeros(curr_batch_size, self.seq_len, self.n_output)
                    for clip in range(curr_batch_size):
                        for k in range(self.seq_len):
                            out[clip][k][top_index[clip][k].item()] = 1

                    output = torch.transpose(output, 1, 2)
                    y_hat = torch.transpose(y, 1, 2).to(device)
                    loss += self.loss_fn(output, y_hat).item()
                    
                    correct, total = accuracy(y.cpu().numpy(), out.cpu().numpy(), correct, total)

                    
            rand_acc = correct / total
            rand_acc_array.append(rand_acc)
        plot = np.percentile(np.sort(np.array(rand_acc_array), axis=0), percentile, axis=0)
        return plot

# %%
def findIndex(val, arr):
    index = -1
    for x in range(arr.size):
        if val == arr[x]:
            index = x
            break
    return index

def accuracy(target, prob, correct, tot):
    for i in range(prob.shape[1]):
        correctCount = correct[i]
        totalCount = tot[i]
        for j in range(prob.shape[0]):
            if np.count_nonzero(target[j][i]) != 0:
                if findIndex(1., target[j][i]) == findIndex(1., prob[j][i]):
                    correctCount += 1
                totalCount += 1
        correct[i] = correctCount
        tot[i] = totalCount
    return correct, tot

# %%
def vectorize(y, c=2):
    new_y = np.zeros((y.shape[0], y.shape[1], c))
    for batch in range(y.shape[0]):
        for time in range(y.shape[1]):
            cl = y[batch][time]
            if cl < c:
                new_y[batch][time][int(cl)] = 1.
    return new_y

# %%
def devector(true, pred):
    new_y_true = []
    new_y_pred = []
    for batch in range(true.shape[0]):
        for time in range(true.shape[1]):
            if np.count_nonzero(true[batch][time]) != 0:
                i = findIndex(1., true[batch][time])
                new_y_true.append(i)
                j = findIndex(1., pred[batch][time])
                new_y_pred.append(j)
    return np.array(new_y_true), np.array(new_y_pred)

# %%
with open(f"appr_retr_timesegments.pkl", 'rb') as f:
    X_train, y_train, len_train, X_test, y_test, len_test = pickle.load(f)

for batch, batch_len in enumerate(len_train):
    y_train[batch, batch_len:] = np.array([2]*(y_train.shape[-1] - batch_len))

for batch, batch_len in enumerate(len_test):
    y_test[batch, batch_len:] = np.array([2]*(y_test.shape[-1] - batch_len))

y_train = vectorize(y_train)
y_test = vectorize(y_test)

batch_size = 32

train_data = TensorDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train).float())
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)
test_data = TensorDataset(torch.from_numpy(X_test).float(), torch.from_numpy(y_test).float())
test_loader = DataLoader(test_data, shuffle=True, batch_size=batch_size)

# %%
n_input = 300
n_hidden = 32
seq_len = 129
learning_rate = 5e-4
EPOCHS = 100
num_head=4
num_layers=1
n_class = 2

transformer_multipos = Transformer(n_input, n_class, seq_len, num_head, n_hidden, num_layers, True).to(device)
loss_fn_multipos = nn.CrossEntropyLoss()
optimizer_multipos = optim.Adam(transformer_multipos.parameters(), lr=learning_rate)

model_multipos = TransformerModel(transformer_multipos, loss_fn_multipos, optimizer_multipos, seq_len, n_class, "transformer_multipos")

# %%
#train_loss_multipos = model_multipos.train(train_loader, n_epochs=EPOCHS, learning=learning_rate)

xAx = [i for i in range(1, EPOCHS+1)]
plt.plot(xAx, train_loss_multipos)
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy Loss")
plt.xlim(0, EPOCHS)
plt.xticks([j*20 for j in range(EPOCHS // 20 + 1)])
plt.title("Training Loss")
plt.show()
# Out:
# Epoch 1/100
# Time: 0 minutes 16 seconds
# Training loss: 14.155397713184357
#
# Epoch 2/100
# Time: 0 minutes 4 seconds
# Training loss: 11.286373130977154
#
# Epoch 3/100
# Time: 0 minutes 4 seconds
# Training loss: 9.963949665427208
#
# Epoch 4/100
# Time: 0 minutes 6 seconds
# Training loss: 8.593271397054195
#
# Epoch 5/100
# Time: 0 minutes 5 seconds
# Training loss: 7.32205605506897
#
# Epoch 6/100
# Time: 0 minutes 4 seconds
# Training loss: 6.597477674484253
#
# Epoch 7/100
# Time: 0 minutes 4 seconds
# Training loss: 6.1146621480584145
#
# Epoch 8/100
# Time: 0 minutes 42 seconds
# Training loss: 5.854114141315222
#
# Epoch 9/100
# Time: 0 minutes 42 seconds
# Training loss: 5.478626109659672
#
# Epoch 10/100
# Time: 0 minutes 3 seconds
# Training loss: 5.2592077776789665
#
# Epoch 11/100
# Time: 0 minutes 3 seconds
# Training loss: 5.038978159427643
#
# Epoch 12/100
# Time: 0 minutes 3 seconds
# Training loss: 4.868833530694246
#
# Epoch 13/100
# Time: 0 minutes 3 seconds
# Training loss: 4.728042244911194
#
# Epoch 14/100
# Time: 0 minutes 3 seconds
# Training loss: 4.5291697308421135
#
# Epoch 15/100
# Time: 0 minutes 3 seconds
# Training loss: 4.462269876152277
#
# Epoch 16/100
# Time: 0 minutes 3 seconds
# Training loss: 4.35966831818223
#
# Epoch 17/100
# Time: 0 minutes 3 seconds
# Training loss: 4.023602779954672
#
# Epoch 18/100
# Time: 0 minutes 3 seconds
# Training loss: 3.845187123864889
#
# Epoch 19/100
# Time: 0 minutes 3 seconds
# Training loss: 3.7110667638480663
#
# Epoch 20/100
# Time: 0 minutes 3 seconds
# Training loss: 3.5464443266391754
#
# Epoch 21/100
# Time: 0 minutes 3 seconds
# Training loss: 3.615402340888977
#
# Epoch 22/100
# Time: 0 minutes 3 seconds
# Training loss: 3.366743616759777
#
# Epoch 23/100
# Time: 0 minutes 4 seconds
# Training loss: 3.1792034059762955
#
# Epoch 24/100
# Time: 0 minutes 3 seconds
# Training loss: 3.0822041016072035
#
# Epoch 25/100
# Time: 0 minutes 5 seconds
# Training loss: 2.941460631787777
#
# Epoch 26/100
# Time: 0 minutes 4 seconds
# Training loss: 2.9645992293953896
#
# Epoch 27/100
# Time: 0 minutes 4 seconds
# Training loss: 2.686521114781499
#
# Epoch 28/100
# Time: 0 minutes 43 seconds
# Training loss: 2.67852227576077
#
# Epoch 29/100
# Time: 0 minutes 34 seconds
# Training loss: 2.591690419241786
#
# Epoch 30/100
# Time: 1 minutes 6 seconds
# Training loss: 2.512840246781707
#
# Epoch 31/100
# Time: 0 minutes 47 seconds
# Training loss: 2.4297889322042465
#
# Epoch 32/100
# Time: 0 minutes 4 seconds
# Training loss: 2.3465072084218264
#
# Epoch 33/100
# Time: 0 minutes 3 seconds
# Training loss: 2.267462346702814
#
# Epoch 34/100
# Time: 0 minutes 5 seconds
# Training loss: 2.0876852963119745
#
# Epoch 35/100
# Time: 0 minutes 4 seconds
# Training loss: 2.141210524365306
#
# Epoch 36/100
# Time: 0 minutes 3 seconds
# Training loss: 1.9476384464651346
#
# Epoch 37/100
# Time: 0 minutes 3 seconds
# Training loss: 1.9458844773471355
#
# Epoch 38/100
# Time: 0 minutes 3 seconds
# Training loss: 1.920334566384554
#
# Epoch 39/100
# Time: 0 minutes 3 seconds
# Training loss: 1.8760925643146038
#
# Epoch 40/100
# Time: 0 minutes 4 seconds
# Training loss: 1.7221192326396704
#
# Epoch 41/100
# Time: 0 minutes 3 seconds
# Training loss: 1.811691788956523
#
# Epoch 42/100
# Time: 0 minutes 3 seconds
# Training loss: 1.5521779228001833
#
# Epoch 43/100
# Time: 0 minutes 3 seconds
# Training loss: 1.7336599715054035
#
# Epoch 44/100
# Time: 0 minutes 4 seconds
# Training loss: 1.518449860624969
#
# Epoch 45/100
# Time: 0 minutes 4 seconds
# Training loss: 1.3877743957564235
#
# Epoch 46/100
# Time: 0 minutes 9 seconds
# Training loss: 1.3960135877132416
#
# Epoch 47/100
# Time: 0 minutes 18 seconds
# Training loss: 1.3860530136153102
#
# Epoch 48/100
# Time: 0 minutes 24 seconds
# Training loss: 1.3570466982200742
#
# Epoch 49/100
# Time: 0 minutes 27 seconds
# Training loss: 1.4901525611057878
#
# Epoch 50/100
# Time: 0 minutes 23 seconds
# Training loss: 1.2034428622573614
#
# Epoch 51/100
# Time: 0 minutes 39 seconds
# Training loss: 1.3487357189878821
#
# Epoch 52/100
# Time: 0 minutes 18 seconds
# Training loss: 1.2475645700469613
#
# Epoch 53/100
# Time: 0 minutes 22 seconds
# Training loss: 1.2015062626451254
#
# Epoch 54/100
# Time: 0 minutes 43 seconds
# Training loss: 1.0395972961559892
#
# Epoch 55/100
# Time: 0 minutes 31 seconds
# Training loss: 1.1387905711308122
#
# Epoch 56/100
# Time: 0 minutes 23 seconds
# Training loss: 1.1421465389430523
#
# Epoch 57/100
# Time: 0 minutes 18 seconds
# Training loss: 1.1127503830939531
#
# Epoch 58/100
# Time: 0 minutes 29 seconds
# Training loss: 0.9971039523370564
#
# Epoch 59/100
# Time: 0 minutes 8 seconds
# Training loss: 1.0654904777184129
#
# Epoch 60/100
# Time: 0 minutes 8 seconds
# Training loss: 1.0180529402568936
#
# Epoch 61/100
# Time: 0 minutes 9 seconds
# Training loss: 1.056186232715845
#
# Epoch 62/100
# Time: 0 minutes 9 seconds
# Training loss: 0.9553303234279156
#
# Epoch 63/100
# Time: 0 minutes 10 seconds
# Training loss: 1.022063447162509
#
# Epoch 64/100
# Time: 0 minutes 9 seconds
# Training loss: 0.935050186701119
#
# Epoch 65/100
# Time: 0 minutes 9 seconds
# Training loss: 0.889283929951489
#
# Epoch 66/100
# Time: 0 minutes 9 seconds
# Training loss: 1.0705820536240935
#
# Epoch 67/100
# Time: 0 minutes 9 seconds
# Training loss: 0.9301629760302603
#
# Epoch 68/100
# Time: 0 minutes 20 seconds
# Training loss: 0.7996094585396349
#
# Epoch 69/100
# Time: 0 minutes 19 seconds
# Training loss: 0.7347405375912786
#
# Epoch 70/100
# Time: 0 minutes 31 seconds
# Training loss: 0.8157043377868831
#
# Epoch 71/100
# Time: 0 minutes 26 seconds
# Training loss: 0.9605708904564381
#
# Epoch 72/100
# Time: 0 minutes 25 seconds
# Training loss: 0.8725006268359721
#
# Epoch 73/100
# Time: 0 minutes 23 seconds
# Training loss: 0.7549995859153569
#
# Epoch 74/100
# Time: 0 minutes 13 seconds
# Training loss: 0.7057596854865551
#
# Epoch 75/100
# Time: 0 minutes 10 seconds
# Training loss: 0.7026234548538923
#
# Epoch 76/100
# Time: 0 minutes 9 seconds
# Training loss: 0.7094203857704997
#
# Epoch 77/100
# Time: 0 minutes 9 seconds
# Training loss: 0.8387930644676089
#
# Epoch 78/100
# Time: 0 minutes 10 seconds
# Training loss: 0.7710338570177555
#
# Epoch 79/100
# Time: 0 minutes 10 seconds
# Training loss: 0.6809563911519945
#
# Epoch 80/100
# Time: 0 minutes 11 seconds
# Training loss: 0.6938771540299058
#
# Epoch 81/100
# Time: 0 minutes 10 seconds
# Training loss: 0.6886758855544031
#
# Epoch 82/100
# Time: 0 minutes 10 seconds
# Training loss: 0.6417758632451296
#
# Epoch 83/100
# Time: 0 minutes 11 seconds
# Training loss: 0.5818540556356311
#
# Epoch 84/100
# Time: 0 minutes 10 seconds
# Training loss: 0.628883074503392
#
# Epoch 85/100
# Time: 0 minutes 9 seconds
# Training loss: 0.6688222652301192
#
# Epoch 86/100
# Time: 0 minutes 9 seconds
# Training loss: 0.7016705879941583
#
# Epoch 87/100
# Time: 0 minutes 8 seconds
# Training loss: 0.6773427431471646
#
# Epoch 88/100
# Time: 0 minutes 9 seconds
# Training loss: 0.6519133648835123
#
# Epoch 89/100
# Time: 1 minutes 12 seconds
# Training loss: 0.5642220838926733
#
# Epoch 90/100
# Time: 0 minutes 45 seconds
# Training loss: 0.567470510257408
#
# Epoch 91/100
# Time: 0 minutes 27 seconds
# Training loss: 0.5346985245123506
#
# Epoch 92/100
# Time: 0 minutes 22 seconds
# Training loss: 0.7162443976849318
#
# Epoch 93/100
# Time: 0 minutes 13 seconds
# Training loss: 0.5541603034362197
#
# Epoch 94/100
# Time: 0 minutes 18 seconds
# Training loss: 0.5695421271957457
#
# Epoch 95/100
# Time: 0 minutes 14 seconds
# Training loss: 0.5330429505556822
#
# Epoch 96/100
# Time: 0 minutes 19 seconds
# Training loss: 0.6570757254958153
#
# Epoch 97/100
# Time: 0 minutes 16 seconds
# Training loss: 0.529098022961989
#
# Epoch 98/100
# Time: 0 minutes 23 seconds
# Training loss: 0.5927925198338926
#
# Epoch 99/100
# Time: 0 minutes 15 seconds
# Training loss: 0.5160263869911432
#
# Epoch 100/100
# Time: 0 minutes 19 seconds
# Training loss: 0.5362329930067062

# %%
transformer_multipos_accuracy, confusion = model_multipos.eval(test_loader)

# %%
# %store transformer_multipos_accuracy
# Out:
# Stored 'transformer_multipos_accuracy' (ndarray)

# %%
print(confusion)
# Out:
# [[46592.  5862.]
#  [ 6218. 47295.]]

# %%
transformer_multipos_rand_acc = model_multipos.rand_test(test_loader, n_samples=20)

# %%
xAx = [i for i in range(1,130)]
plt.plot(xAx, transformer_multipos_accuracy, label="transformer-multi-pos")
plt.plot(xAx, transformer_multipos_rand_acc, label="random-multi-pos")
plt.xlabel("Time (s)")
plt.ylabel("Accuracy")
plt.ylim(0,1)
plt.xlim(0,130)
plt.title("Time-varying Classification Accuracy")
plt.legend()
plt.show()
