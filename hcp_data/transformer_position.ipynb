# %% [markdown]
# # Position Encoding

# %%
import numpy as np
import pickle
import time
from matplotlib import pyplot as plt
import gc
import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

from lstm_data_prep import numpy_prep
from eval_model import epoch_time, find_lens, accuracy

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
class Transformer(nn.Module):
    def __init__(self, n_input, n_output, seq_len, n_head, dim_ff, num_layers, position_encoding):
        super().__init__()

        self.n_input = n_input
        self.n_output = n_output
        self.n_head = n_head
        self.dim_ff = dim_ff
        self.num_layers = num_layers
        self.position_encoding = position_encoding
        self.seq_len = seq_len

        self.transformerlayer = nn.TransformerEncoderLayer(n_input, n_head, dim_feedforward=dim_ff, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(self.transformerlayer, num_layers)
        self.fc = nn.Linear(n_input, n_output)

    def position_encode(self):
        pe = torch.zeros(self.seq_len, self.n_input).to(device)
        pos = torch.arange(0, self.seq_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, self.n_input, 2).float() * (-np.log(10000.0) / self.n_input))

        pe[:, 0::2] = torch.sin(pos * div_term)
        pe[:, 1::2] = torch.cos(pos * div_term)
        pe = pe.unsqueeze(0)
        return pe
    
    def forward(self, X):
        x = X.to(device)
        if self.position_encoding:
            pe = self.position_encode()
            pe = pe.expand(X.size(0), -1, -1)
            x = X + pe
        y = self.transformer_encoder(x)
        y = self.fc(y)
        return y

# %%
class TransformerModel:
    def __init__(self, model, loss_fn, optimizer, seq_len, model_name):
        self.model = model
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.seq_len = seq_len
        self.model_name = model_name
        
        total_params = sum(p.numel() for p in self.model.parameters())
        print(total_params)

    def train(self, train_loader, n_epochs, learning):
        train_loss = []
        best_loss = 1e10

        self.model.train()
        
        for i in range(n_epochs):
            start = time.time()
            avg_loss = 0.
            for X, y in train_loader:
                loss = 0.
                curr_batch_size = X.shape[0]

                X, y = X.to(device), y.to(device)
                self.optimizer.zero_grad()

                output = self.model(X)

                out = output.permute(0, 2, 1)
                target = y.permute(0, 2, 1)

                loss += self.loss_fn(out, target)
                
                loss.backward()
                self.optimizer.step()
                avg_loss += loss.item()

            end = time.time()
            epoch_mins, epoch_secs = epoch_time(start, end)
            if best_loss > avg_loss:
                best_loss = avg_loss
                torch.save({self.model_name: self.model.state_dict(), self.model_name+"_optimizer": self.optimizer.state_dict()}, self.model_name+'-model.pt')
            print("Epoch " + str(i + 1) + "/" + str(n_epochs))
            print("Time: " + str(epoch_mins) + " minutes " + str(epoch_secs) + " seconds")
            print("Training loss: " + str(avg_loss))
            print()

            train_loss.append(avg_loss)
            
        return train_loss
    
    def eval(self, test_loader):
        check = torch.load(self.model_name+"-model.pt")
        self.model.load_state_dict(check[self.model_name])

        gc.collect()
        torch.cuda.empty_cache()

        with torch.no_grad():
            correct = np.zeros(self.seq_len)
            total = np.zeros(self.seq_len)
            self.model.eval()

            for x, y in test_loader:
                loss = 0.
                curr_batch_size = x.shape[0]
                X, Y = x.to(device), y.to(device)

                out = self.model(X)

                top_value, top_index = out.topk(1)

                final = torch.zeros(y.shape).to(device)
                for clip in range(y.shape[0]):
                    for step in range(y.shape[1]):
                        final[clip][step][top_index[clip][step]] = 1
                
                correct, total = accuracy(y.cpu().numpy(), final.cpu().numpy(), correct, total)
        
        eval_accuracy = correct / total
        return eval_accuracy, loss
    
    def random_samples(self, X, pad=0.):
        X_random = []
        X_lens = find_lens(X)
        for i in range(X.shape[0]):
            X_batch = np.random.normal(size=(X_lens[i], X.shape[-1]))
            if X_lens[i] < self.seq_len:
                X_pad = np.array([[pad]*X.shape[-1]]*(self.seq_len - X_lens[i]))
                X_batch = np.append(X_batch, X_pad, axis=0)
            X_random.append(X_batch)
        X_random = np.array(X_random)
        return X_random
    
    def rand_test(self, test_loader, n_samples=100, percentile=90):
        rand_acc_array = []
        for sample in range(n_samples):
            correct = np.zeros(self.seq_len)
            total = np.zeros(self.seq_len)
            
            self.model.eval()

            for x, y in test_loader:
                loss = 0.
                curr_batch_size = x.shape[0]
                X_random = torch.from_numpy(self.random_samples(x)).float().to(device)
                Y = y.to(device)

                out = self.model(X_random)

                top_value, top_index = out.topk(1)
                final = torch.zeros(y.shape).to(device)
                for clip in range(y.shape[0]):
                    for step in range(y.shape[1]):
                        final[clip][step][top_index[clip][step]] = 1
                
                correct, total = accuracy(y.cpu().numpy(), final.cpu().numpy(), correct, total)
            gru_rand_acc = correct / total
            rand_acc_array.append(gru_rand_acc)
        plot = np.percentile(np.sort(np.array(rand_acc_array), axis=0), percentile, axis=0)
        return plot

# %%
with open('HCP_movie_watching.pkl','rb') as f:
    TS = pickle.load(f)

X_train, y_train, X_t, y_t = numpy_prep(TS, pad = 0.)

batch_size = 32

train_data = TensorDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train).float())
train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size)
test_data = TensorDataset(torch.from_numpy(X_t).float(), torch.from_numpy(y_t).float())
test_loader = DataLoader(test_data, shuffle=True, batch_size=batch_size)
# Out:
# c:\Users\annax\Documents\GitHub\srp-lab-notebook\hcp_data\lstm_data_prep.py:58: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_padded = paddingArr(np.array(X_arr), pad=pad)

# %%
n_input = 300
dim_ff = 32
n_out = 15
seq_len = 90
learning_rate = 1e-3
EPOCHS = 50
position_encoding = True
num_head=1
num_layers=1

transformer_pos = Transformer(n_input, n_out, seq_len, num_head, dim_ff, num_layers, True).to(device)
loss_fn_pos = nn.CrossEntropyLoss()
optimizer_pos = optim.Adam(transformer_pos.parameters(), lr=learning_rate)

model_pos = TransformerModel(transformer_pos, loss_fn_pos, optimizer_pos, seq_len, "transformer_pos")
# Out:
# 768379

# %%
train_loss_pos = model_pos.train(train_loader, n_epochs=EPOCHS, learning=learning_rate)

xAx = [i for i in range(1, EPOCHS+1)]
plt.plot(xAx, train_loss_pos)
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy Loss")
plt.xlim(0, EPOCHS)
plt.xticks([j*5 for j in range(EPOCHS//5)])
plt.title("Training Loss")
# Out:
# Epoch 1/50
# Time: 0 minutes 6 seconds
# Training loss: 109.99072688817978
#
# Epoch 2/50
# Time: 0 minutes 0 seconds
# Training loss: 43.628543704748154
#
# Epoch 3/50
# Time: 0 minutes 0 seconds
# Training loss: 26.343611985445023
#
# Epoch 4/50
# Time: 0 minutes 0 seconds
# Training loss: 21.256084442138672
#
# Epoch 5/50
# Time: 0 minutes 0 seconds
# Training loss: 14.013068154454231
#
# Epoch 6/50
# Time: 0 minutes 0 seconds
# Training loss: 11.294177908450365
#
# Epoch 7/50
# Time: 0 minutes 0 seconds
# Training loss: 9.690221764147282
#
# Epoch 8/50
# Time: 0 minutes 0 seconds
# Training loss: 7.097199860960245
#
# Epoch 9/50
# Time: 0 minutes 0 seconds
# Training loss: 5.918977566063404
#
# Epoch 10/50
# Time: 0 minutes 0 seconds
# Training loss: 4.890382840298116
#
# Epoch 11/50
# Time: 0 minutes 0 seconds
# Training loss: 11.570493519306183
#
# Epoch 12/50
# Time: 0 minutes 0 seconds
# Training loss: 4.945258589461446
#
# Epoch 13/50
# Time: 0 minutes 0 seconds
# Training loss: 3.151157951913774
#
# Epoch 14/50
# Time: 0 minutes 0 seconds
# Training loss: 2.600219771731645
#
# Epoch 15/50
# Time: 0 minutes 0 seconds
# Training loss: 2.1763241020962596
#
# Epoch 16/50
# Time: 0 minutes 0 seconds
# Training loss: 2.101130375638604
#
# Epoch 17/50
# Time: 0 minutes 0 seconds
# Training loss: 5.820022216998041
#
# Epoch 18/50
# Time: 0 minutes 0 seconds
# Training loss: 8.90180517733097
#
# Epoch 19/50
# Time: 0 minutes 0 seconds
# Training loss: 8.31446816585958
#
# Epoch 20/50
# Time: 0 minutes 0 seconds
# Training loss: 2.5097374697215855
#
# Epoch 21/50
# Time: 0 minutes 0 seconds
# Training loss: 0.835547863971442
#
# Epoch 22/50
# Time: 0 minutes 0 seconds
# Training loss: 0.34371430150349624
#
# Epoch 23/50
# Time: 0 minutes 0 seconds
# Training loss: 0.23694049438927323
#
# Epoch 24/50
# Time: 0 minutes 0 seconds
# Training loss: 0.21756795118562877
#
# Epoch 25/50
# Time: 0 minutes 0 seconds
# Training loss: 0.18191250588279217
#
# Epoch 26/50
# Time: 0 minutes 0 seconds
# Training loss: 0.16707710269838572
#
# Epoch 27/50
# Time: 0 minutes 0 seconds
# Training loss: 0.15552017459413037
#
# Epoch 28/50
# Time: 0 minutes 0 seconds
# Training loss: 0.1457863922114484
#
# Epoch 29/50
# Time: 0 minutes 0 seconds
# Training loss: 0.1344677610322833
#
# Epoch 30/50
# Time: 0 minutes 0 seconds
# Training loss: 0.12457108788657933
#
# Epoch 31/50
# Time: 0 minutes 0 seconds
# Training loss: 0.12691393750719726
#
# Epoch 32/50
# Time: 0 minutes 0 seconds
# Training loss: 0.11041333619505167
#
# Epoch 33/50
# Time: 0 minutes 0 seconds
# Training loss: 0.1028635730035603
#
# Epoch 34/50
# Time: 0 minutes 0 seconds
# Training loss: 0.1027377899736166
#
# Epoch 35/50
# Time: 0 minutes 0 seconds
# Training loss: 0.09206636593444273
#
# Epoch 36/50
# Time: 0 minutes 0 seconds
# Training loss: 0.07147334031469654
#
# Epoch 37/50
# Time: 0 minutes 0 seconds
# Training loss: 0.07719316511065699
#
# Epoch 38/50
# Time: 0 minutes 0 seconds
# Training loss: 0.074844972405117
#
# Epoch 39/50
# Time: 0 minutes 0 seconds
# Training loss: 0.07473477584426291
#
# Epoch 40/50
# Time: 0 minutes 0 seconds
# Training loss: 0.07283735736564267
#
# Epoch 41/50
# Time: 0 minutes 0 seconds
# Training loss: 0.06943040264013689
#
# Epoch 42/50
# Time: 0 minutes 0 seconds
# Training loss: 0.06997344753472134
#
# Epoch 43/50
# Time: 0 minutes 0 seconds
# Training loss: 0.0767101092642406
#
# Epoch 44/50
# Time: 0 minutes 0 seconds
# Training loss: 0.06415867482428439
#
# Epoch 45/50
# Time: 0 minutes 0 seconds
# Training loss: 0.06020561620243825
#
# Epoch 46/50
# Time: 0 minutes 0 seconds
# Training loss: 0.06007687083911151
#
# Epoch 47/50
# Time: 0 minutes 0 seconds
# Training loss: 0.05693204345880076
#
# Epoch 48/50
# Time: 0 minutes 0 seconds
# Training loss: 0.05529181041492848
#
# Epoch 49/50
# Time: 0 minutes 0 seconds
# Training loss: 0.05917214798682835
#
# Epoch 50/50
# Time: 0 minutes 0 seconds
# Training loss: 10.324099571356783
# Text(0.5, 1.0, 'Training Loss')

# %%
transformer_pos_acc, loss = model_pos.eval(test_loader)
# %store transformer_pos_acc
np.save('transformer_pos_acc.npy', transformer_pos_acc)
# Out:
# Stored 'transformer_pos_acc' (ndarray)

# %%
transformer_pos_rand_acc = model_pos.rand_test(test_loader)
# %store transformer_pos_rand_acc

# %%
learning_rate = 1e-3
EPOCHS = 50
num_head = 4
num_layers=1

transformer_multipos = Transformer(n_input, n_out, seq_len, num_head, dim_ff, num_layers, True).to(device)
loss_fn_multipos = nn.CrossEntropyLoss()
optimizer_multipos = optim.Adam(transformer_multipos.parameters(), lr=learning_rate)

model_multipos = TransformerModel(transformer_multipos, loss_fn_multipos, optimizer_multipos, seq_len, "transformer_multipos")

train_loss_multipos = model_multipos.train(train_loader, n_epochs=EPOCHS, learning=learning_rate)

xAx = [i for i in range(1, EPOCHS+1)]
plt.plot(xAx, train_loss_multipos)
plt.xlabel("Epoch")
plt.ylabel("Cross Entropy Loss")
plt.xlim(0, EPOCHS)
plt.xticks([j*5 + 1 for j in range(EPOCHS // 5)])
plt.title("Training Loss")
plt.show()

# %%
transformer_multipos_acc, loss = model_multipos.eval(test_loader)
# %store transformer_multipos_acc
np.save('transformer_multipos_acc.npy', transformer_multipos_acc)
# Out:
# Stored 'transformer_multipos_acc' (ndarray)

# %%
transformer_multipos_rand_acc = model_multipos.rand_test(test_loader)
# %store transformer_multipos_rand_acc

# %%
xAx = [i for i in range(0,90)]
plt.plot(xAx, transformer_pos_acc, label="transformer-pos")
#plt.plot(xAx, transformer_pos_rand_acc, label="random-pos")
plt.xlabel("Time (s)")
plt.ylabel("Accuracy")
plt.ylim(0,1)
plt.xlim(0,90)
plt.title("Time-varying Classification Accuracy")
plt.legend()
plt.show()

# %%
xAx = [i for i in range(0,90)]
plt.plot(xAx, transformer_multipos_acc, label="transformer-multi-pos")
#plt.plot(xAx, transformer_multipos_rand_acc, label="random-multi-pos")
plt.xlabel("Time (s)")
plt.ylabel("Accuracy")
plt.ylim(0,1)
plt.xlim(0,90)
plt.title("Time-varying Classification Accuracy")
plt.legend()
plt.show()
